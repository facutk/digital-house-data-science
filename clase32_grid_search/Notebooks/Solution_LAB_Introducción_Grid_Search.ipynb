# %% [markdown]
# # LAB: Estimando hiperparámetros con `GridSearchCV` para SVC y KNN

# %% [markdown]
# ## Introducción

# %% [markdown]
# El objetivo de esta práctica es que puedan comenzar a tunear hiperparámetros usando Cross Validation. Para eso, usaremos `GridSearchCV`.
#
# Utilizaremos el dataset ya trabajado sobre cáncer de mama. Contiene información de estudios clínicos y celulares. El objetivo es predecir el carácter benigno ($class_t=0$) maligno ($class_t=1) del cáncer en función de una serie de predictores a nivel celular.
#
#     + class_t es la variable target
#     + el resto son variables con valores normalizados de 1 a 10
#
# [Aquí](https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.names) pueden encontrar más información sobre el dataset.
#
# **Nota:** se eliminaron del dataset original 16 casos con valores perdidos en algunos campos.

# %% [markdown]
# ## Tareas

# %% [markdown]
# Para esta práctica deberá
#
# 1. Construir dos clasificadores: Support Vector Machines y K-Vecinos más Cercanos (KNN)
# 2. Estimar los hiperpáremtros del modelo
#
#           *2.1 SVM:* deberá tunear un modelo con kernel lineal y C's = 1, 10, 100, 1000; y otro con kernel rbf, C=1, 10, 100, 1000 y [gamma](http://scikit-learn.org/stable/auto_examples/svm/plot_rbf_parameters.html) = 0.1, 0.01, 0.001, 0.0001, 0.00001
#
#           *2.2 KNN:* deberá tunear tanto el parámetro k, como la medida del peso dado a los K vecinos (uniforme o distancia). También podría probar con el parámetro p que define el tipo de distancia con el que se calculan los vecinos más cercanos.
#
# 3. Estimar los modelos finales
# 4. Evaluar cuál de los dos performa mejor
#
# **Importante:** recuerde que deberá diseñar cuidadosamente las diferentes estrategias de validación de las diferentes etapas de estimación del modelo.

# %% [markdown]
# Importamos los paquetes necesarios

# %%
from sklearn import svm, linear_model
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import datasets
from sklearn.preprocessing import normalize

# %% [markdown]
# Importamos el dataset

# %%
df = pd.read_csv('breast-cancer.csv', header = None)
df.columns = ['ID', 'clump_Thickness', 'unif_cell_size', 'unif_cell_shape', 'adhesion', 'epith_cell_Size', 'bare_nuclei',
              'bland_chromatin ','norm_nucleoli', 'mitoses', 'class_t']

# %% [markdown]
# Recodificamos las clases en "0" y "1"

# %%
df.class_t[df['class_t'] == 2] = 0
df.class_t[df['class_t'] == 4] = 1

# %% [markdown]
# Hacemos el split entre target y features

# %%
X = (df.iloc[:,1:9])
y = df['class_t']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

# %% [markdown]
# **Pista 1:** Conviene realizar dos listas, una con los estimadores de los modelos y otra con la grid de parámetros a estimar en cada modelo.
#
# **Pista 2:** Conviene iterar sobre esas listas para estimar los hiperparámetros de los modelos

# %%
models = [svm.SVC(),
          KNeighborsClassifier()]

# %%
params = [
    
    [
        {'C': [1, 10, 100, 1000], 'kernel': ['linear']},
          
        {'C': [1, 10, 100, 1000], 'gamma': [0.1, 0.01, 0.001, 0.0001, 0.00001], 'kernel': ['rbf']}
    ],
          {'n_neighbors': range(1,200),
           'weights' : ['uniform', 'distance'],
           'p' : [1, 2, 3]}
]

# %%
grids = []
for i in range(len(models)):
    gs = GridSearchCV(estimator=models[i], param_grid=params[i], scoring='accuracy', cv=10, n_jobs=4)
    print (gs)
    fit = gs.fit(X_train, y_train)
    grids.append(fit)
# Out:
# GridSearchCV(cv=10, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params={}, iid=True, n_jobs=4,
#        param_grid=[{'C': [1, 10, 100, 1000], 'kernel': ['linear']}, {'C': [1, 10, 100, 1000], 'gamma': [0.1, 0.01, 0.001, 0.0001, 1e-05], 'kernel': ['rbf']}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='accuracy', verbose=0)
# GridSearchCV(cv=10, error_score='raise',
#        estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform'),
#        fit_params={}, iid=True, n_jobs=4,
#        param_grid={'n_neighbors': range(1, 200), 'weights': ['uniform', 'distance'], 'p': [1, 2, 3]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='accuracy', verbose=0)

# %%
for i in grids:
    print (i.best_score_)
    print (i.best_estimator_)
    print (i.best_params_)
# Out:
# 0.973105134474
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.0001, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.975550122249
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# {'n_neighbors': 5, 'p': 2, 'weights': 'distance'}

# %%
pd.DataFrame(grids[0].cv_results_)
# Out:
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score param_C  \
# 0        0.006847         0.002157         0.968215          0.973104       1
# 1        0.027923         0.000737         0.968215          0.973648      10
# 2        0.186663         0.000688         0.968215          0.973648     100
# 3        1.426656         0.000512         0.968215          0.973648    1000
# 4        0.005193         0.000762         0.960880          0.995381       1
# 5        0.004793         0.001186         0.968215          0.973377       1
# 6        0.007169         0.001033         0.970660          0.972018       1
# 7        0.007061         0.001332         0.965770          0.967670       1
# 8        0.008921         0.001294         0.677262          0.677262       1
# 9        0.008022         0.001347         0.963325          1.000000      10
# 10       0.005359         0.000988         0.958435          0.990764      10
# 11       0.003611         0.000895         0.970660          0.973105      10
# 12       0.005335         0.001030         0.973105          0.973377      10
# 13       0.006180         0.001297         0.965770          0.967670      10
# 14       0.006993         0.001138         0.963325          1.000000     100
# 15       0.005176         0.000794         0.953545          1.000000     100
# 16       0.005496         0.000708         0.970660          0.975823     100
# 17       0.003417         0.000813         0.970660          0.972019     100
# 18       0.003611         0.000847         0.973105          0.973648     100
# 19       0.007082         0.001157         0.963325          1.000000    1000
# 20       0.005558         0.000764         0.953545          1.000000    1000
# 21       0.007062         0.000805         0.948655          0.988591    1000
# 22       0.004662         0.000863         0.968215          0.974191    1000
# 23       0.003304         0.000838         0.970660          0.971746    1000
#
#    param_gamma param_kernel                                         params  \
# 0          NaN       linear                   {'C': 1, 'kernel': 'linear'}
# 1          NaN       linear                  {'C': 10, 'kernel': 'linear'}
# 2          NaN       linear                 {'C': 100, 'kernel': 'linear'}
# 3          NaN       linear                {'C': 1000, 'kernel': 'linear'}
# 4          0.1          rbf        {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 5         0.01          rbf       {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 6        0.001          rbf      {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 7       0.0001          rbf     {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 8        1e-05          rbf      {'C': 1, 'gamma': 1e-05, 'kernel': 'rbf'}
# 9          0.1          rbf       {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 10        0.01          rbf      {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 11       0.001          rbf     {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 12      0.0001          rbf    {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 13       1e-05          rbf     {'C': 10, 'gamma': 1e-05, 'kernel': 'rbf'}
# 14         0.1          rbf      {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# 15        0.01          rbf     {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 16       0.001          rbf    {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 17      0.0001          rbf   {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 18       1e-05          rbf    {'C': 100, 'gamma': 1e-05, 'kernel': 'rbf'}
# 19         0.1          rbf     {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
# 20        0.01          rbf    {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# 21       0.001          rbf   {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 22      0.0001          rbf  {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 23       1e-05          rbf   {'C': 1000, 'gamma': 1e-05, 'kernel': 'rbf'}
#
#     rank_test_score  split0_test_score       ...         split7_test_score  \
# 0                 8           1.000000       ...                     0.975
# 1                 8           1.000000       ...                     0.975
# 2                 8           1.000000       ...                     0.975
# 3                 8           1.000000       ...                     0.975
# 4                19           1.000000       ...                     0.975
# 5                 8           1.000000       ...                     1.000
# 6                 3           1.000000       ...                     1.000
# 7                14           1.000000       ...                     0.975
# 8                24           0.666667       ...                     0.675
# 9                16           1.000000       ...                     0.975
# 10               20           1.000000       ...                     0.975
# 11                3           1.000000       ...                     1.000
# 12                1           1.000000       ...                     1.000
# 13               14           1.000000       ...                     0.975
# 14               16           1.000000       ...                     0.975
# 15               21           0.976190       ...                     0.950
# 16                3           1.000000       ...                     1.000
# 17                3           1.000000       ...                     1.000
# 18                1           1.000000       ...                     1.000
# 19               16           1.000000       ...                     0.975
# 20               21           0.976190       ...                     0.950
# 21               23           0.976190       ...                     0.950
# 22                8           1.000000       ...                     0.975
# 23                3           1.000000       ...                     1.000
#
#     split7_train_score  split8_test_score  split8_train_score  \
# 0             0.972900              0.975            0.972900
# 1             0.972900              0.975            0.972900
# 2             0.972900              0.975            0.972900
# 3             0.972900              0.975            0.972900
# 4             0.997290              0.950            0.994580
# 5             0.970190              0.975            0.972900
# 6             0.967480              0.975            0.972900
# 7             0.967480              0.975            0.967480
# 8             0.677507              0.675            0.677507
# 9             1.000000              0.975            1.000000
# 10            0.991870              0.975            0.989160
# 11            0.970190              0.975            0.972900
# 12            0.970190              0.975            0.972900
# 13            0.967480              0.975            0.967480
# 14            1.000000              0.975            1.000000
# 15            1.000000              0.950            1.000000
# 16            0.972900              0.975            0.975610
# 17            0.967480              0.975            0.972900
# 18            0.970190              0.975            0.972900
# 19            1.000000              0.975            1.000000
# 20            1.000000              0.950            1.000000
# 21            0.991870              0.975            0.983740
# 22            0.972900              0.975            0.972900
# 23            0.967480              0.975            0.972900
#
#     split9_test_score  split9_train_score  std_fit_time  std_score_time  \
# 0               0.975            0.972900      0.001869        0.003694
# 1               0.975            0.972900      0.010789        0.000072
# 2               0.975            0.972900      0.067837        0.000242
# 3               0.975            0.972900      0.644500        0.000047
# 4               0.975            0.994580      0.001717        0.000226
# 5               0.950            0.972900      0.001060        0.000799
# 6               0.975            0.972900      0.004816        0.000353
# 7               0.950            0.967480      0.002914        0.000548
# 8               0.675            0.677507      0.002593        0.000172
# 9               0.975            1.000000      0.000581        0.000358
# 10              0.950            0.989160      0.001758        0.000290
# 11              0.975            0.972900      0.000775        0.000491
# 12              0.975            0.972900      0.002556        0.000534
# 13              0.950            0.967480      0.000751        0.000614
# 14              0.975            1.000000      0.000436        0.000429
# 15              0.950            1.000000      0.000791        0.000109
# 16              0.975            0.972900      0.001469        0.000033
# 17              0.975            0.970190      0.000586        0.000404
# 18              0.975            0.975610      0.000396        0.000380
# 19              0.975            1.000000      0.000509        0.000366
# 20              0.950            1.000000      0.000727        0.000061
# 21              0.975            0.986450      0.001068        0.000114
# 22              0.975            0.975610      0.000715        0.000429
# 23              0.975            0.970190      0.000380        0.000416
#
#     std_test_score  std_train_score
# 1179       0.007760         0.007784         0.946210          1.000000
# 1180       0.003321         0.021235         0.921760          0.923661
# 1181       0.002289         0.022351         0.943765          1.000000
# 1182       0.003050         0.005728         0.909535          0.912251
# 1183       0.007922         0.007706         0.941320          1.000000
# 1184       0.006630         0.008053         0.916870          0.918229
# 1185       0.006222         0.003201         0.946210          1.000000
# 1186       0.002287         0.020037         0.919315          0.921489
# 1187       0.001716         0.016618         0.943765          1.000000
# 1188       0.002768         0.003072         0.909535          0.912523
# 1189       0.003565         0.006743         0.938875          1.000000
# 1190       0.015468         0.009286         0.916870          0.918229
# 1191       0.005157         0.019159         0.946210          1.000000
# 1192       0.002967         0.024068         0.919315          0.921489
# 1193       0.001715         0.017153         0.943765          1.000000
#
#      param_n_neighbors param_p param_weights  \
# 0                    1       1       uniform
# 1                    1       1      distance
# 2                    1       2       uniform
# 3                    1       2      distance
# 4                    1       3       uniform
# 5                    1       3      distance
# 6                    2       1       uniform
# 7                    2       1      distance
# 8                    2       2       uniform
# 9                    2       2      distance
# 10                   2       3       uniform
# 11                   2       3      distance
# 12                   3       1       uniform
# 13                   3       1      distance
# 14                   3       2       uniform
# 15                   3       2      distance
# 16                   3       3       uniform
# 17                   3       3      distance
# 18                   4       1       uniform
# 19                   4       1      distance
# 20                   4       2       uniform
# 21                   4       2      distance
# 22                   4       3       uniform
# 23                   4       3      distance
# 24                   5       1       uniform
# 25                   5       1      distance
# 26                   5       2       uniform
# 27                   5       2      distance
# 28                   5       3       uniform
# 29                   5       3      distance
# ...                ...     ...           ...
# 1164               195       1       uniform
# 1165               195       1      distance
# 1166               195       2       uniform
# 1167               195       2      distance
# 1168               195       3       uniform
# 1169               195       3      distance
# 1170               196       1       uniform
# 1171               196       1      distance
# 1172               196       2       uniform
# 1173               196       2      distance
# 1174               196       3       uniform
# 1175               196       3      distance
# 1176               197       1       uniform
# 1177               197       1      distance
# 1178               197       2       uniform
# 1179               197       2      distance
# 1180               197       3       uniform
# 1181               197       3      distance
# 1182               198       1       uniform
# 1183               198       1      distance
# 1184               198       2       uniform
# 1185               198       2      distance
# 1186               198       3       uniform
# 1187               198       3      distance
# 1188               199       1       uniform
# 1189               199       1      distance
# 1190               199       2       uniform
# 1191               199       2      distance
# 1192               199       3       uniform
# 1193               199       3      distance
#
#                                                  params  rank_test_score  \
# 0      {'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}               43
# 1     {'n_neighbors': 1, 'p': 1, 'weights': 'distance'}               43
# 2      {'n_neighbors': 1, 'p': 2, 'weights': 'uniform'}              342
# 3     {'n_neighbors': 1, 'p': 2, 'weights': 'distance'}              342
# 4      {'n_neighbors': 1, 'p': 3, 'weights': 'uniform'}              573
# 5     {'n_neighbors': 1, 'p': 3, 'weights': 'distance'}              573
# 6      {'n_neighbors': 2, 'p': 1, 'weights': 'uniform'}              883
# 7     {'n_neighbors': 2, 'p': 1, 'weights': 'distance'}              342
# 8      {'n_neighbors': 2, 'p': 2, 'weights': 'uniform'}             1092
# 9     {'n_neighbors': 2, 'p': 2, 'weights': 'distance'}              342
# 10     {'n_neighbors': 2, 'p': 3, 'weights': 'uniform'}             1000
# 11    {'n_neighbors': 2, 'p': 3, 'weights': 'distance'}              573
# 12     {'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}               12
# 13    {'n_neighbors': 3, 'p': 1, 'weights': 'distance'}               12
# 14     {'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}               43
# 15    {'n_neighbors': 3, 'p': 2, 'weights': 'distance'}               43
# 16     {'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}               43
# 17    {'n_neighbors': 3, 'p': 3, 'weights': 'distance'}               43
# 18     {'n_neighbors': 4, 'p': 1, 'weights': 'uniform'}              342
# 19    {'n_neighbors': 4, 'p': 1, 'weights': 'distance'}               43
# 20     {'n_neighbors': 4, 'p': 2, 'weights': 'uniform'}               99
# 21    {'n_neighbors': 4, 'p': 2, 'weights': 'distance'}               12
# 22     {'n_neighbors': 4, 'p': 3, 'weights': 'uniform'}               99
# 23    {'n_neighbors': 4, 'p': 3, 'weights': 'distance'}               43
# 24     {'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}               99
# 25    {'n_neighbors': 5, 'p': 1, 'weights': 'distance'}               43
# 26     {'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}               12
# 27    {'n_neighbors': 5, 'p': 2, 'weights': 'distance'}                1
# 28     {'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}               43
# 29    {'n_neighbors': 5, 'p': 3, 'weights': 'distance'}               12
# ...                                                 ...              ...
# 1164  {'n_neighbors': 195, 'p': 1, 'weights': 'unifo...             1189
# 1165  {'n_neighbors': 195, 'p': 1, 'weights': 'dista...             1073
# 1166  {'n_neighbors': 195, 'p': 2, 'weights': 'unifo...             1165
# 1167  {'n_neighbors': 195, 'p': 2, 'weights': 'dista...             1000
# 1168  {'n_neighbors': 195, 'p': 3, 'weights': 'unifo...             1165
# 1169  {'n_neighbors': 195, 'p': 3, 'weights': 'dista...              961
# 1170  {'n_neighbors': 196, 'p': 1, 'weights': 'unifo...             1192
# 1171  {'n_neighbors': 196, 'p': 1, 'weights': 'dista...             1073
# 1172  {'n_neighbors': 196, 'p': 2, 'weights': 'unifo...             1181
# 1173  {'n_neighbors': 196, 'p': 2, 'weights': 'dista...             1000
# 1174  {'n_neighbors': 196, 'p': 3, 'weights': 'unifo...             1165
# 1175  {'n_neighbors': 196, 'p': 3, 'weights': 'dista...             1000
# 1176  {'n_neighbors': 197, 'p': 1, 'weights': 'unifo...             1190
# 1177  {'n_neighbors': 197, 'p': 1, 'weights': 'dista...             1073
# 1178  {'n_neighbors': 197, 'p': 2, 'weights': 'unifo...             1181
# 1179  {'n_neighbors': 197, 'p': 2, 'weights': 'dista...             1000
# 1180  {'n_neighbors': 197, 'p': 3, 'weights': 'unifo...             1165
# 1181  {'n_neighbors': 197, 'p': 3, 'weights': 'dista...             1044
# 1182  {'n_neighbors': 198, 'p': 1, 'weights': 'unifo...             1192
# 1183  {'n_neighbors': 198, 'p': 1, 'weights': 'dista...             1073
# 1184  {'n_neighbors': 198, 'p': 2, 'weights': 'unifo...             1181
# 1185  {'n_neighbors': 198, 'p': 2, 'weights': 'dista...             1000
# 1186  {'n_neighbors': 198, 'p': 3, 'weights': 'unifo...             1174
# 1187  {'n_neighbors': 198, 'p': 3, 'weights': 'dista...             1044
# 1188  {'n_neighbors': 199, 'p': 1, 'weights': 'unifo...             1192
# 1189  {'n_neighbors': 199, 'p': 1, 'weights': 'dista...             1092
# 1190  {'n_neighbors': 199, 'p': 2, 'weights': 'unifo...             1181
# 1191  {'n_neighbors': 199, 'p': 2, 'weights': 'dista...             1000
# 1192  {'n_neighbors': 199, 'p': 3, 'weights': 'unifo...             1174
# 1193  {'n_neighbors': 199, 'p': 3, 'weights': 'dista...             1044
#
#       split0_test_score       ...         split7_test_score  \
# 0              1.000000       ...                     0.975
# 1              1.000000       ...                     0.975
# 2              1.000000       ...                     0.975
# 3              1.000000       ...                     0.975
# 4              1.000000       ...                     0.975
# 5              1.000000       ...                     0.975
# 6              0.976190       ...                     0.950
# 7              1.000000       ...                     0.975
# 8              1.000000       ...                     0.975
# 9              1.000000       ...                     0.975
# 10             1.000000       ...                     0.950
# 11             1.000000       ...                     0.975
# 12             1.000000       ...                     1.000
# 13             1.000000       ...                     1.000
# 14             1.000000       ...                     1.000
# 15             1.000000       ...                     1.000
# 16             1.000000       ...                     1.000
# 17             1.000000       ...                     1.000
# 18             1.000000       ...                     0.975
# 19             1.000000       ...                     1.000
# 20             1.000000       ...                     1.000
# 21             1.000000       ...                     1.000
# 22             1.000000       ...                     1.000
# 23             1.000000       ...                     1.000
# 24             1.000000       ...                     0.975
# 25             1.000000       ...                     0.975
# 26             1.000000       ...                     1.000
# 27             1.000000       ...                     1.000
# 28             1.000000       ...                     1.000
# 29             1.000000       ...                     1.000
# ...                 ...       ...                       ...
# 1164           0.904762       ...                     0.925
# 1165           0.952381       ...                     0.925
# 1166           0.880952       ...                     0.925
# 1167           0.952381       ...                     0.925
# 1168           0.880952       ...                     0.925
# 1169           0.952381       ...                     0.925
# 1170           0.904762       ...                     0.925
# 1171           0.952381       ...                     0.925
# 1172           0.880952       ...                     0.925
# 1173           0.952381       ...                     0.925
# 1174           0.880952       ...                     0.925
# 1175           0.952381       ...                     0.925
# 1176           0.904762       ...                     0.925
# 1177           0.952381       ...                     0.925
# 1178           0.880952       ...                     0.925
# 1179           0.952381       ...                     0.925
# 1180           0.880952       ...                     0.925
# 1181           0.952381       ...                     0.925
# 1182           0.904762       ...                     0.925
# 1183           0.952381       ...                     0.925
# 1184           0.880952       ...                     0.925
# 1185           0.952381       ...                     0.925
# 1186           0.880952       ...                     0.925
# 1187           0.952381       ...                     0.925
# 1188           0.904762       ...                     0.925
# 1189           0.952381       ...                     0.925
# 1190           0.880952       ...                     0.925
# 1191           0.952381       ...                     0.925
# 1192           0.880952       ...                     0.925
# 1193           0.952381       ...                     0.925
#
#       split7_train_score  split8_test_score  split8_train_score  \
# 0               1.000000              0.950            1.000000
# 1               1.000000              0.950            1.000000
# 2               1.000000              0.950            1.000000
# 3               1.000000              0.950            1.000000
# 4               1.000000              0.950            1.000000
# 5               1.000000              0.950            1.000000
# 6               0.983740              0.950            0.981030
# 7               1.000000              0.950            1.000000
# 8               0.983740              0.950            0.986450
# 9               1.000000              0.950            1.000000
# 10              0.978320              0.950            0.983740
# 11              1.000000              0.950            1.000000
# 12              0.975610              0.975            0.981030
# 13              1.000000              0.975            1.000000
# 1180        0.031924         0.004478
# 1181        0.034901         0.000000
# 1182        0.043817         0.004735
# 1183        0.039895         0.000000
# 1184        0.036350         0.004770
# 1185        0.036107         0.000000
# 1186        0.032534         0.003537
# 1187        0.034901         0.000000
# 1188        0.043817         0.004837
# 1189        0.038384         0.000000
# 1190        0.036350         0.004770
# 1191        0.036107         0.000000
# 1192        0.032534         0.003537
# 1193        0.034901         0.000000
#
# [1194 rows x 33 columns]

# %%
y_preds_svm = grids[0].predict(X_test)
y_preds_knn = grids[1].predict(X_test)

# %%
print (classification_report(y_test, y_preds_svm), confusion_matrix(y_test, y_preds_svm))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.95      0.98      0.96       167
#           1       0.96      0.93      0.94       107
#
# avg / total       0.96      0.96      0.96       274
#  [[163   4]
#  [  8  99]]

# %%
print (classification_report(y_test, y_preds_knn), confusion_matrix(y_test, y_preds_knn))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97       167
#           1       0.96      0.94      0.95       107
#
# avg / total       0.96      0.96      0.96       274
#  [[163   4]
#  [  6 101]]

# %% [markdown]
# ## Diferencia de performance entre Random Search y Gridsearch
#
# Dado el siguiente conjunto de parámetros:
#
#         param_dist = {
#                     "C": [0.1, 0.5, 0.8, 1, 10, 100, 1000],
#                     "kernel": ['linear','rbf'],
#                     "gamma": [0.1, 0.01, 0.001, 0.0001, 0.00001]
#                      }
#
# Implementar una búsqueda del conjunto óptimo de hiperparámetros tanto con GridSearchCV como con RandomSearchCV.
# Verificar la diferencia en cada caso de:
#
#     1. El tiempo de ejecución (utilizando la magic function %%time)
#     2. La combinación óptima de parámetros
#     3. La performance del mejor modelo en cada caso sobre los datos del test set que separamos anteriormente en términos de accuracy

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
def busquedaGridsearch(params_):
    gs = GridSearchCV(estimator=svm.SVC(), param_grid=params_, scoring='accuracy', cv=10, n_jobs=4)
    fit = gs.fit(X_train, y_train)
    return gs

# %%
def busquedaRandomSearch(params_,iter_):
    gs = RandomizedSearchCV(estimator=svm.SVC(), param_distributions=params_, scoring='accuracy', cv=10, n_jobs=4, n_iter = iter_ )
    fit = gs.fit(X_train, y_train)
    return gs

# %%
param_dist = {
            "C": [0.1, 0.5, 0.8, 1, 10, 100, 1000],
            "kernel": ['linear','rbf'],
            "gamma": [0.1, 0.01, 0.001, 0.0001, 0.00001]
             }

# %%
# %%time
gs_random_search = busquedaRandomSearch(param_dist,10)
# Out:
# CPU times: user 140 ms, sys: 44 ms, total: 184 ms
# Wall time: 14.6 s

# %%
# %%time
gs_grid_search = busquedaGridsearch(param_dist)
# Out:
# CPU times: user 764 ms, sys: 48 ms, total: 812 ms
# Wall time: 45.5 s

# %%
gs_random_search.best_params_
# Out:
# {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}

# %%
gs_grid_search.best_params_
# Out:
# {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}

# %%
from sklearn.metrics import accuracy_score

def obtener_performance(estimator):
    y_pred = estimator.predict(X_test)
    return accuracy_score(y_pred,y_test, normalize = True)

# %%
obtener_performance(gs_grid_search.best_estimator_)
# Out:
# 0.95620437956204385

# %%
obtener_performance(gs_random_search.best_estimator_)
# Out:
# 0.96350364963503654
