# %%
import pandas as pd

# %%
df = pd.read_csv('big_clarin.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.sample(20)
# Out:
#                                             articleBody  \
# 130   El sostenido viento Zonda, caliente y seco, pr...
# 1107  Un nuevo informe sobre los ingresos que necesi...
# 357   -¿Cómo es posible colocar un dispositivo incen...
# 509   La investigación por el crimen de Anahí Beníte...
# 62    Juan Gatti conserva intacto su espíritu lúdico...
# 1034  "Te imaginás que yo contra esa chica no puedo ...
# 64    Con una brecha de 10 puntos de diferencia entr...
# 100   "Soy fan de Ishiguro. Lo que queda del día, y ...
# 107   La previa del duelo entre Argentina y Perú ya ...
# 960   De cara a las elecciones, Macri apuesta todo a...
# 179   Procesada por lavado de dinero y asociación il...
# 939   El atentado en Irán tendrá indudables repercus...
# 317   Hay escuelas que pierden clases por paros. Otr...
# 910   Miami, enviado. Esta es la capital de Latinoam...
# 1111  La llegada de Mauricio Macri a China persigue ...
# 414   Los resultados del escrutinio definitivo de la...
# 748   Muchas de las críticas contra la situación eco...
# 837   María Eugenia Vidal se comunicó hoy con Esteba...
# 178   El fiscal Germán Moldes respaldó a su colega d...
# 33    SeriesThe SonDomingo, a las 22, por AMC Estren...
#
#                                                  bajada  \
# 130   Algunos pobladores dicen que les cuesta respir...
# 1107  La canasta de alimentos y servicios para un ma...
# 357   El ministro de Seguridad dice que "no vamos a ...
# 509   Es un hombre que vive en una casilla a unos 30...
# 62    El artista presenta "Transhispania", la muestr...
# 1034  La líder de la CC confía en su relación person...
# 64    Cinco de los seis gremios del sector negocian ...
# 100   Murakami era candidato favorito para el Nobel....
# 107   Un numeroso grupo de visitantes se quedó afuer...
# 960   Desembolsaron ya $ 56.400 millones en rutas, t...
# 179   Es porque ocupa un ambiente en el local que us...
# 939   El papel de Irán como único país promotor del ...
# 317   Los alumnos y docentes de la secundaria N° 27 ...
# 910   Inauguran obras de Fabián Burgos y Eduardo Cap...
# 1111  La Argentina dice que tiene un déficit de casi...
# 414   Se destacó el fuerte crecimiento que tuvo el f...
# 748   Un documento académico publicado por el vicemi...
# 837   Se lo confirmaron fuentes oficiales a Clarín. ...
# 178   El fiscal de la Cámara Federal dictaminó que l...
# 33    Una guía para ver lo mejor en el cable básico,...
#
#                             date  \
# 130   2017-09-30 18:39:16.736814
# 1107  2017-05-13 19:43:49.482891
# 357   2017-08-26 18:54:47.482820
# 509   2017-08-06 19:03:28.340420
# 62    2017-10-10 18:34:42.394063
# 1034  2017-05-23 19:39:03.898504
# 64    2017-10-10 18:34:42.394063
# 100   2017-10-05 18:37:01.277935
# 107   2017-10-05 18:37:01.277935
# 960   2017-06-02 19:34:17.585337
# 179   2017-09-25 18:41:33.901483
# 939   2017-06-07 19:31:53.615359
# 317   2017-09-05 18:50:47.659873
# 910   2017-06-12 19:29:30.227135
# 1111  2017-05-13 19:43:49.482891
# 414   2017-08-21 18:57:07.249439
# 748   2017-07-02 19:20:04.409594
# 837   2017-06-22 19:24:47.118020
# 178   2017-09-25 18:41:33.901483
# 33    2017-10-15 18:32:35.075360
#
#                                                headline       section  \
# 130   El viento Zonda propaga un incendio forestal q...      Sociedad
# 1107  Por la inflación, una familia necesita más de ...      Economía
# 357   Cristian Ritondo: "Hay un sector que está espe...      Política
# 509            Un nuevo detenido por el crimen de Anahí    Policiales
# 62     "En la política argentina aún hay mucho armario"       Cultura
# 1034  Mundo Carrió: los amigos y enemigos internos d...      Política
# 64    Se complica la paritaria aeronáutica y podría ...      Política
# 100                               ¿Murakami o Ishiguro?       Cultura
# 107   Vergonzoso: unos 600 hinchas peruanos con entr...      Deportes
# 960   Odebrecht más obra pública: Macri apuesta todo...      Política
# 179   Intiman a la sobrina de Cristina para que aban...      Política
# 939   Un episodio que pone en duda las acusaciones d...         Mundo
# 317   Otra escuela sin clases por culpa de los robos...    Policiales
# 910      Paseo con los argentinos que intervienen Miami       Cultura
# 1111  Una insólita diferencia con China complica las...      Economía
# 414   Escrutinio definitivo en 12 provincias: Cambie...      Política
# 748   Luces y sombras en el futuro del empleo indust...      Economía
# 837   Alejandro Finocchiaro será el próximo ministro...      Sociedad
# 178   Caso Maldonado: dictaminan que la denuncia con...      Política
# 33    Recomendados de series y películas para la semana  Espectáculos
#
#                                               volanta
# 130   Cerro de la Santa Cruz y San Juan de los Sauces
# 1107                               Canasta de consumo
# 357                                       Entrevista.
# 509                                Un caso impactante
# 62                                         Juan Gatti
# 1034                         La coalición oficialista
# 64                                            Gremios
# 100                                Opinan los autores
# 107                                Eliminatorias 2018
# 960                                           En Foco
# 179                           Sospechas de corrupción
# 939                      El atentado del ISIS en Irán
# 317                                          La Plata
# 910                         Diálogo con los artistas.
# 1111                    La gira presidencial por Asia
# 414      Comparación en las categorías para diputados
# 748                            La creación de trabajo
# 837                            Cambios en el Gobierno
# 178                               Santiago Maldonado.
# 33              Del lunes 16 al domingo 22 de octubre

# %%
X = df[['articleBody']]
y = df[['section']]

# %%
import numpy as np
np.unique(y.values)
# Out:
# array(['ARQ', 'Autos', 'Cartas al pais', 'Ciudades', 'Clarín em Portugues',
#        'Cultura', 'Deportes', 'Economía', 'Entremujeres', 'Espectáculos',
#        'Mundo', 'Noticias', 'Opinión', 'Policiales', 'Política',
#        'Revista Ñ', 'Rural', 'Sociedad', 'Tecnología', 'Viajes', 'Viva'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB
modeo_nb = GaussianNB()
modeo_nb.fit(X, Y)
GaussianNB(priors=None)
print(clf.predict([[-0.8, -1]]))
